# %% [markdown]
# GitHub Machine Learning Repositories Analysis
#
# ## Task 1: Data Collection and Preparation
#
# In this task, repository data is collected from the GitHub API, explored and prepared using Python and Pandas. The dataset is cleaned, structured, and saved as a CSV file for the next stages of the project.

# %%
import requests
import pandas as pd

# %% [markdown]
#  1. Fetch Data from GitHub API
#
# The GitHub API is used to collect information about Machine Learning repositories. The repositories are sorted by the number of stars in descending order.

# %%
url = "https://api.github.com/search/repositories?q=machine+learning&sort=stars&order=desc&per_page=100"

response = requests.get(url)
response.raise_for_status()

data = response.json()

print("Data collected successfully.")
print("Number of repositories:", len(data["items"]))
# Out:
# Data collected successfully.
# Number of repositories: 100

# %% [markdown]
# 2. Create and Explore the DataFrame
#
# The JSON response contains repository information inside the items field. This data is converted into a Pandas DataFrame for exploration and preparation.

# %%
df = pd.DataFrame(data["items"])

print("Dataset shape:", df.shape)

df.head()
# Out:
# Dataset shape: (100, 82)
#           id                           node_id                      name  \
# 0   45717250  MDEwOlJlcG9zaXRvcnk0NTcxNzI1MA==                tensorflow
# 1  155220641  MDEwOlJlcG9zaXRvcnkxNTUyMjA2NDE=              transformers
# 2  343965132  MDEwOlJlcG9zaXRvcnkzNDM5NjUxMzI=          ML-For-Beginners
# 3  145553672  MDEwOlJlcG9zaXRvcnkxNDU1NTM2NzI=                    funNLP
# 4   21872392  MDEwOlJlcG9zaXRvcnkyMTg3MjM5Mg==  awesome-machine-learning
#
#                                full_name  private  \
# 0                  tensorflow/tensorflow    False
# 1               huggingface/transformers    False
# 2             microsoft/ML-For-Beginners    False
# 3                  fighting41love/funNLP    False
# 4  josephmisiti/awesome-machine-learning    False
#
#                                                owner  \
# 0  {'login': 'tensorflow', 'id': 15658638, 'node_...
# 1  {'login': 'huggingface', 'id': 25720743, 'node...
# 2  {'login': 'microsoft', 'id': 6154722, 'node_id...
# 3  {'login': 'fighting41love', 'id': 11475294, 'n...
# 4  {'login': 'josephmisiti', 'id': 246302, 'node_...
#
#                                             html_url  \
# 0           https://github.com/tensorflow/tensorflow
# 1        https://github.com/huggingface/transformers
# 2      https://github.com/microsoft/ML-For-Beginners
# 3           https://github.com/fighting41love/funNLP
# 4  https://github.com/josephmisiti/awesome-machin...
#
#                                          description   fork  \
# 0  An Open Source Machine Learning Framework for ...  False
# 1  🤗 Transformers: the model-definition framework...  False
# 2  12 weeks, 26 lessons, 52 quizzes, classic Mach...  False
# 3  中英文敏感词、语言检测、中外手机/电话归属地/运营商查询、名字推断性别、手机号抽取、身份证抽...  False
# 4  A curated list of awesome Machine Learning fra...  False
#
#                                                  url  ...  \
# 0  https://api.github.com/repos/tensorflow/tensor...  ...
# 1  https://api.github.com/repos/huggingface/trans...  ...
# 2  https://api.github.com/repos/microsoft/ML-For-...  ...
# 3  https://api.github.com/repos/fighting41love/fu...  ...
# 4  https://api.github.com/repos/josephmisiti/awes...  ...
#
#   web_commit_signoff_required has_pull_requests pull_request_creation_policy  \
# 0                       False              True                          all
# 1                       False              True                          all
# 2                       False              True                          all
# 3                       False              True                          all
# 4                       False              True                          all
#
#                                               topics visibility  forks  \
# 0  [deep-learning, deep-neural-networks, distribu...     public  76059
# 1  [audio, deep-learning, deepseek, gemma, glm, h...     public  34269
# 2  [data-science, education, machine-learning, ma...     public  21970
# 3                                                 []     public  15264
# 4                                                 []     public  15612
#
#   open_issues watchers default_branch score
# 0        3013   197048         master   1.0
# 1        2366   164227           main   1.0
# 2          12    89495           main   1.0
# 3          52    82527         master   1.0
# 4          26    74066         master   1.0
#
# [5 rows x 82 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 82 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            100 non-null    int64
#  1   node_id                       100 non-null    object
#  2   name                          100 non-null    object
#  3   full_name                     100 non-null    object
#  4   private                       100 non-null    bool
#  5   owner                         100 non-null    object
#  6   html_url                      100 non-null    object
#  7   description                   100 non-null    object
#  8   fork                          100 non-null    bool
#  9   url                           100 non-null    object
#  10  forks_url                     100 non-null    object
#  11  keys_url                      100 non-null    object
#  12  collaborators_url             100 non-null    object
#  13  teams_url                     100 non-null    object
#  14  hooks_url                     100 non-null    object
#  15  issue_events_url              100 non-null    object
#  16  events_url                    100 non-null    object
#  17  assignees_url                 100 non-null    object
#  18  branches_url                  100 non-null    object
#  19  tags_url                      100 non-null    object
#  20  blobs_url                     100 non-null    object
#  21  git_tags_url                  100 non-null    object
#  22  git_refs_url                  100 non-null    object
#  23  trees_url                     100 non-null    object
#  24  statuses_url                  100 non-null    object
#  25  languages_url                 100 non-null    object
#  26  stargazers_url                100 non-null    object
#  27  contributors_url              100 non-null    object
#  28  subscribers_url               100 non-null    object
#  29  subscription_url              100 non-null    object
#  30  commits_url                   100 non-null    object
#  31  git_commits_url               100 non-null    object
#  32  comments_url                  100 non-null    object
#  33  issue_comment_url             100 non-null    object
#  34  contents_url                  100 non-null    object
#  35  compare_url                   100 non-null    object
#  36  merges_url                    100 non-null    object
#  37  archive_url                   100 non-null    object
#  38  downloads_url                 100 non-null    object
#  39  issues_url                    100 non-null    object
#  40  pulls_url                     100 non-null    object
#  41  milestones_url                100 non-null    object
#  42  notifications_url             100 non-null    object
#  43  labels_url                    100 non-null    object
#  44  releases_url                  100 non-null    object
#  45  deployments_url               100 non-null    object
#  46  created_at                    100 non-null    object
#  47  updated_at                    100 non-null    object
#  48  pushed_at                     100 non-null    object
#  49  git_url                       100 non-null    object
#  50  ssh_url                       100 non-null    object
#  51  clone_url                     100 non-null    object
#  52  svn_url                       100 non-null    object
#  53  homepage                      92 non-null     object
#  54  size                          100 non-null    int64
#  55  stargazers_count              100 non-null    int64
#  56  watchers_count                100 non-null    int64
#  57  language                      77 non-null     object
#  58  has_issues                    100 non-null    bool
#  59  has_projects                  100 non-null    bool
#  60  has_downloads                 100 non-null    bool
#  61  has_wiki                      100 non-null    bool
#  62  has_pages                     100 non-null    bool
#  63  has_discussions               100 non-null    bool
#  64  forks_count                   100 non-null    int64
#  65  mirror_url                    0 non-null      object
#  66  archived                      100 non-null    bool
#  67  disabled                      100 non-null    bool
#  68  open_issues_count             100 non-null    int64
#  69  license                       78 non-null     object
#  70  allow_forking                 100 non-null    bool
#  71  is_template                   100 non-null    bool
#  72  web_commit_signoff_required   100 non-null    bool
#  73  has_pull_requests             100 non-null    bool
#  74  pull_request_creation_policy  100 non-null    object
#  75  topics                        100 non-null    object
#  76  visibility                    100 non-null    object
#  77  forks                         100 non-null    int64
#  78  open_issues                   100 non-null    int64
#  79  watchers                      100 non-null    int64
#  80  default_branch                100 non-null    object
#  81  score                         100 non-null    float64
# dtypes: bool(14), float64(1), int64(9), object(58)
# memory usage: 54.6+ KB

# %%
df.columns.tolist()
# Out:
# ['id',
#  'node_id',
#  'name',
#  'full_name',
#  'private',
#  'owner',
#  'html_url',
#  'description',
#  'fork',
#  'url',
#  'forks_url',
#  'keys_url',
#  'collaborators_url',
#  'teams_url',
#  'hooks_url',
#  'issue_events_url',
#  'events_url',
#  'assignees_url',
#  'branches_url',
#  'tags_url',
#  'blobs_url',
#  'git_tags_url',
#  'git_refs_url',
#  'trees_url',
#  'statuses_url',
#  'languages_url',
#  'stargazers_url',
#  'contributors_url',
#  'subscribers_url',
#  'subscription_url',
#  'commits_url',
#  'git_commits_url',
#  'comments_url',
#  'issue_comment_url',
#  'contents_url',
#  'compare_url',
#  'merges_url',
#  'archive_url',
#  'downloads_url',
#  'issues_url',
#  'pulls_url',
#  'milestones_url',
#  'notifications_url',
#  'labels_url',
#  'releases_url',
#  'deployments_url',
#  'created_at',
#  'updated_at',
#  'pushed_at',
#  'git_url',
#  'ssh_url',
#  'clone_url',
#  'svn_url',
#  'homepage',
#  'size',
#  'stargazers_count',
#  'watchers_count',
#  'language',
#  'has_issues',
#  'has_projects',
#  'has_downloads',
#  'has_wiki',
#  'has_pages',
#  'has_discussions',
#  'forks_count',
#  'mirror_url',
#  'archived',
#  'disabled',
#  'open_issues_count',
#  'license',
#  'allow_forking',
#  'is_template',
#  'web_commit_signoff_required',
#  'has_pull_requests',
#  'pull_request_creation_policy',
#  'topics',
#  'visibility',
#  'forks',
#  'open_issues',
#  'watchers',
#  'default_branch',
#  'score']

# %% [markdown]
# 3. Select Relevant Fields
#
# The dataset contains many fields returned by the GitHub API. Only the fields needed for the analysis are selected.

# %%
selected_columns = [
    "name",
    "full_name",
    "html_url",
    "description",
    "language",
    "stargazers_count",
    "forks_count",
    "open_issues_count",
    "created_at",
    "updated_at",
    "owner",
    "license"
]

df = df[selected_columns]

df.head()
# Out:
#                        name                              full_name  \
# 0                tensorflow                  tensorflow/tensorflow
# 1              transformers               huggingface/transformers
# 2          ML-For-Beginners             microsoft/ML-For-Beginners
# 3                    funNLP                  fighting41love/funNLP
# 4  awesome-machine-learning  josephmisiti/awesome-machine-learning
#
#                                             html_url  \
# 0           https://github.com/tensorflow/tensorflow
# 1        https://github.com/huggingface/transformers
# 2      https://github.com/microsoft/ML-For-Beginners
# 3           https://github.com/fighting41love/funNLP
# 4  https://github.com/josephmisiti/awesome-machin...
#
#                                          description          language  \
# 0  An Open Source Machine Learning Framework for ...               C++
# 1  🤗 Transformers: the model-definition framework...            Python
# 2  12 weeks, 26 lessons, 52 quizzes, classic Mach...  Jupyter Notebook
# 3  中英文敏感词、语言检测、中外手机/电话归属地/运营商查询、名字推断性别、手机号抽取、身份证抽...            Python
# 4  A curated list of awesome Machine Learning fra...            Python
#
#    stargazers_count  forks_count  open_issues_count            created_at  \
# 0            197048        76059               3013  2015-11-07T01:19:20Z
# 1            164227        34269               2366  2018-10-29T13:56:00Z
# 2             89495        21970                 12  2021-03-03T01:34:05Z
# 3             82527        15264                 52  2018-08-21T11:20:39Z
# 4             74066        15612                 26  2014-07-15T19:11:19Z
#
#              updated_at                                              owner  \
# 0  2026-08-19T00:37:37Z  {'login': 'tensorflow', 'id': 15658638, 'node_...
# 1  2026-08-19T00:36:41Z  {'login': 'huggingface', 'id': 25720743, 'node...
# 2  2026-08-19T01:22:22Z  {'login': 'microsoft', 'id': 6154722, 'node_id...
# 3  2026-08-19T00:34:50Z  {'login': 'fighting41love', 'id': 11475294, 'n...
# 4  2026-08-19T01:17:05Z  {'login': 'josephmisiti', 'id': 246302, 'node_...
#
#                                              license
# 0  {'key': 'apache-2.0', 'name': 'Apache License ...
# 1  {'key': 'apache-2.0', 'name': 'Apache License ...
# 2  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 3                                               None
# 4  {'key': 'other', 'name': 'Other', 'spdx_id': '...

# %% [markdown]
# 4. Extract Nested Data
#
# Some repository information is stored inside nested objects. The owner's login name and license name are extracted into separate columns to make the dataset easier to analyze and store in a database.

# %%
df["owner_login"] = df["owner"].apply(
    lambda x: x.get("login") if isinstance(x, dict) else None
)

df["license_name"] = df["license"].apply(
    lambda x: x.get("name") if isinstance(x, dict) else None
)

df = df.drop(columns=["owner", "license"])

df.head()
# Out:
#                        name                              full_name  \
# 0                tensorflow                  tensorflow/tensorflow
# 1              transformers               huggingface/transformers
# 2          ML-For-Beginners             microsoft/ML-For-Beginners
# 3                    funNLP                  fighting41love/funNLP
# 4  awesome-machine-learning  josephmisiti/awesome-machine-learning
#
#                                             html_url  \
# 0           https://github.com/tensorflow/tensorflow
# 1        https://github.com/huggingface/transformers
# 2      https://github.com/microsoft/ML-For-Beginners
# 3           https://github.com/fighting41love/funNLP
# 4  https://github.com/josephmisiti/awesome-machin...
#
#                                          description          language  \
# 0  An Open Source Machine Learning Framework for ...               C++
# 1  🤗 Transformers: the model-definition framework...            Python
# 2  12 weeks, 26 lessons, 52 quizzes, classic Mach...  Jupyter Notebook
# 3  中英文敏感词、语言检测、中外手机/电话归属地/运营商查询、名字推断性别、手机号抽取、身份证抽...            Python
# 4  A curated list of awesome Machine Learning fra...            Python
#
#    stargazers_count  forks_count  open_issues_count            created_at  \
# 0            197048        76059               3013  2015-11-07T01:19:20Z
# 1            164227        34269               2366  2018-10-29T13:56:00Z
# 2             89495        21970                 12  2021-03-03T01:34:05Z
# 3             82527        15264                 52  2018-08-21T11:20:39Z
# 4             74066        15612                 26  2014-07-15T19:11:19Z
#
#              updated_at     owner_login        license_name
# 0  2026-08-19T00:37:37Z      tensorflow  Apache License 2.0
# 1  2026-08-19T00:36:41Z     huggingface  Apache License 2.0
# 2  2026-08-19T01:22:22Z       microsoft         MIT License
# 3  2026-08-19T00:34:50Z  fighting41love                None
# 4  2026-08-19T01:17:05Z    josephmisiti               Other

# %% [markdown]
# 5. Explore Missing and Duplicate Data
#
# The dataset is checked for missing values and duplicate records before cleaning.

# %%
print("Missing values before cleaning:")
print(df.isnull().sum())
# Out:
# Missing values before cleaning:
# name                  0
# full_name             0
# html_url              0
# description           0
# language             23
# stargazers_count      0
# forks_count           0
# open_issues_count     0
# created_at            0
# updated_at            0
# owner_login           0
# license_name         22
# dtype: int64

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# 6. Clean the Dataset
#
# Missing values in text fields are replaced with suitable values, and duplicate records are removed

# %%
df["description"] = df["description"].fillna("No description")
df["language"] = df["language"].fillna("Unknown")
df["owner_login"] = df["owner_login"].fillna("Unknown")
df["license_name"] = df["license_name"].fillna("No license")

df = df.drop_duplicates()

print("Dataset shape after cleaning:", df.shape)
# Out:
# Dataset shape after cleaning: (100, 12)

# %% [markdown]
# 7. Prepare Data Types
#
# Date columns are converted to datetime format, while numerical columns are converted to numeric values to prepare the dataset for database storage and analysis.

# %%
df["created_at"] = pd.to_datetime(df["created_at"])
df["updated_at"] = pd.to_datetime(df["updated_at"])

numeric_columns = [
    "stargazers_count",
    "forks_count",
    "open_issues_count"
]

for column in numeric_columns:
    df[column] = pd.to_numeric(df[column], errors="coerce")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               100 non-null    object
#  1   full_name          100 non-null    object
#  2   html_url           100 non-null    object
#  3   description        100 non-null    object
#  4   language           100 non-null    object
#  5   stargazers_count   100 non-null    int64
#  6   forks_count        100 non-null    int64
#  7   open_issues_count  100 non-null    int64
#  8   created_at         100 non-null    datetime64[ns, UTC]
#  9   updated_at         100 non-null    datetime64[ns, UTC]
#  10  owner_login        100 non-null    object
#  11  license_name       100 non-null    object
# dtypes: datetime64[ns, UTC](2), int64(3), object(7)
# memory usage: 9.5+ KB

# %% [markdown]
# 8. Final Dataset Check
#
# The cleaned dataset is checked again to make sure that the required fields are available and the data is ready to be saved.

# %%
print("Final dataset shape:", df.shape)

print("\nMissing values after cleaning:")
print(df.isnull().sum())

print("\nDuplicate rows after cleaning:")
print(df.duplicated().sum())

df.head()
# Out:
# Final dataset shape: (100, 12)
#
# Missing values after cleaning:
# name                 0
# full_name            0
# html_url             0
# description          0
# language             0
# stargazers_count     0
# forks_count          0
# open_issues_count    0
# created_at           0
# updated_at           0
# owner_login          0
# license_name         0
# dtype: int64
#
# Duplicate rows after cleaning:
# 0
#                        name                              full_name  \
# 0                tensorflow                  tensorflow/tensorflow
# 1              transformers               huggingface/transformers
# 2          ML-For-Beginners             microsoft/ML-For-Beginners
# 3                    funNLP                  fighting41love/funNLP
# 4  awesome-machine-learning  josephmisiti/awesome-machine-learning
#
#                                             html_url  \
# 0           https://github.com/tensorflow/tensorflow
# 1        https://github.com/huggingface/transformers
# 2      https://github.com/microsoft/ML-For-Beginners
# 3           https://github.com/fighting41love/funNLP
# 4  https://github.com/josephmisiti/awesome-machin...
#
#                                          description          language  \
# 0  An Open Source Machine Learning Framework for ...               C++
# 1  🤗 Transformers: the model-definition framework...            Python
# 2  12 weeks, 26 lessons, 52 quizzes, classic Mach...  Jupyter Notebook
# 3  中英文敏感词、语言检测、中外手机/电话归属地/运营商查询、名字推断性别、手机号抽取、身份证抽...            Python
# 4  A curated list of awesome Machine Learning fra...            Python
#
#    stargazers_count  forks_count  open_issues_count                created_at  \
# 0            197048        76059               3013 2015-11-07 01:19:20+00:00
# 1            164227        34269               2366 2018-10-29 13:56:00+00:00
# 2             89495        21970                 12 2021-03-03 01:34:05+00:00
# 3             82527        15264                 52 2018-08-21 11:20:39+00:00
# 4             74066        15612                 26 2014-07-15 19:11:19+00:00
#
#                  updated_at     owner_login        license_name
# 0 2026-08-19 00:37:37+00:00      tensorflow  Apache License 2.0
# 1 2026-08-19 00:36:41+00:00     huggingface  Apache License 2.0
# 2 2026-08-19 01:22:22+00:00       microsoft         MIT License
# 3 2026-08-19 00:34:50+00:00  fighting41love          No license
# 4 2026-08-19 01:17:05+00:00    josephmisiti               Other

# %% [markdown]
# 9. Save the Prepared Dataset
#
# The final prepared dataset is saved as github_projects.csv.

# %%
df.to_csv("github_projects.csv", index=False)

print("github_projects.csv saved successfully.")
# Out:
# github_projects.csv saved successfully.

# %% [markdown]
# 10. Verify the Saved Dataset
#
# The saved CSV file is loaded again to verify that the data was stored correctly and is ready for the next stage of the project.

# %%
df_check = pd.read_csv("github_projects.csv")

print("Reloaded dataset shape:", df_check.shape)

df_check.head()
# Out:
# Reloaded dataset shape: (100, 12)
#                        name                              full_name  \
# 0                tensorflow                  tensorflow/tensorflow
# 1              transformers               huggingface/transformers
# 2          ML-For-Beginners             microsoft/ML-For-Beginners
# 3                    funNLP                  fighting41love/funNLP
# 4  awesome-machine-learning  josephmisiti/awesome-machine-learning
#
#                                             html_url  \
# 0           https://github.com/tensorflow/tensorflow
# 1        https://github.com/huggingface/transformers
# 2      https://github.com/microsoft/ML-For-Beginners
# 3           https://github.com/fighting41love/funNLP
# 4  https://github.com/josephmisiti/awesome-machin...
#
#                                          description          language  \
# 0  An Open Source Machine Learning Framework for ...               C++
# 1  🤗 Transformers: the model-definition framework...            Python
# 2  12 weeks, 26 lessons, 52 quizzes, classic Mach...  Jupyter Notebook
# 3  中英文敏感词、语言检测、中外手机/电话归属地/运营商查询、名字推断性别、手机号抽取、身份证抽...            Python
# 4  A curated list of awesome Machine Learning fra...            Python
#
#    stargazers_count  forks_count  open_issues_count  \
# 0            197048        76059               3013
# 1            164227        34269               2366
# 2             89495        21970                 12
# 3             82527        15264                 52
# 4             74066        15612                 26
#
#                   created_at                 updated_at     owner_login  \
# 0  2015-11-07 01:19:20+00:00  2026-08-19 00:37:37+00:00      tensorflow
# 1  2018-10-29 13:56:00+00:00  2026-08-19 00:36:41+00:00     huggingface
# 2  2021-03-03 01:34:05+00:00  2026-08-19 01:22:22+00:00       microsoft
# 3  2018-08-21 11:20:39+00:00  2026-08-19 00:34:50+00:00  fighting41love
# 4  2014-07-15 19:11:19+00:00  2026-08-19 01:17:05+00:00    josephmisiti
#
#          license_name
# 0  Apache License 2.0
# 1  Apache License 2.0
# 2         MIT License
# 3          No license
# 4               Other

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               100 non-null    object
#  1   full_name          100 non-null    object
#  2   html_url           100 non-null    object
#  3   description        100 non-null    object
#  4   language           100 non-null    object
#  5   stargazers_count   100 non-null    int64
#  6   forks_count        100 non-null    int64
#  7   open_issues_count  100 non-null    int64
#  8   created_at         100 non-null    object
#  9   updated_at         100 non-null    object
#  10  owner_login        100 non-null    object
#  11  license_name       100 non-null    object
# dtypes: int64(3), object(9)
# memory usage: 9.5+ KB

# %% [markdown]
# Task 1 Completed
#
# The GitHub repository data was collected through the GitHub API, converted into a Pandas DataFrame, explored, and prepared. Relevant fields were selected, nested owner and license information was extracted, missing and duplicate data was handled, data types were prepared, and the final dataset was saved and verified as github_projects.csv.

# %% [markdown]
# Task 2: Data Storage and Analysis
#
# In this task, the prepared GitHub repository dataset is stored in a SQLite database and analyzed using SQL. The analysis includes filtering, searching, logical operators, sorting, aggregate functions, grouping, and data visualization using Matplotlib.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Create SQLite Database
#
# The prepared CSV dataset from Task 1 is loaded and stored in a SQLite database. The data is imported into a table named Repositories.

# %%
df = pd.read_csv("github_projects.csv")

conn = sqlite3.connect("github_projects.db")

df.to_sql("Repositories", conn, if_exists="replace", index=False)

print("Data imported successfully into the Repositories table.")
# Out:
# Data imported successfully into the Repositories table.

# %% [markdown]
# 2. Filtering Repositories by Stars
#
# This query filters repositories that have more than 10,000 stars.
# Cell 6 — Code

# %%
query = """
SELECT name, stargazers_count, language
FROM Repositories
WHERE stargazers_count > 10000
"""

over_10000 = pd.read_sql_query(query, conn)

over_10000
# Out:
#                                name  stargazers_count          language
# 0                        tensorflow            197048               C++
# 1                      transformers            164227            Python
# 2                  ML-For-Beginners             89495  Jupyter Notebook
# 3                            funNLP             82527            Python
# 4          awesome-machine-learning             74066            Python
# ..                              ...               ...               ...
# 65  machine-learning-systems-design             10530              HTML
# 66                 Machine-Learning             10370            Python
# 67           machine-learning-notes             10331  Jupyter Notebook
# 68              3D-Machine-Learning             10193           Unknown
# 69                             tpot             10051  Jupyter Notebook
#
# [70 rows x 3 columns]

# %% [markdown]
# 3. Searching Repository Names
#
# This query finds repositories whose names contain the word "Machine".

# %%
query = """
SELECT name, stargazers_count, language
FROM Repositories
WHERE name LIKE '%Machine%'
"""

machine_repositories = pd.read_sql_query(query, conn)

machine_repositories
# Out:
#                                                  name  stargazers_count  \
# 0                            awesome-machine-learning             74066
# 1   500-AI-Machine-learning-Deep-learning-Computer...             36371
# 2             machine-learning-for-software-engineers             28863
# 3                           homemade-machine-learning             24766
# 4                 awesome-production-machine-learning             20852
# 5                        machine-learning-for-trading             20506
# 6                    stanford-cs-229-machine-learning             20128
# 7                          Machine-Learning-Tutorials             18108
# 8                           machine-learning-zoomcamp             13940
# 9                          machine-learning-interview             12783
# 10                       python-machine-learning-book             12641
# 11                         dive-into-machine-learning             11392
# 12                    machine-learning-systems-design             10530
# 13                                   Machine-Learning             10370
# 14                             machine-learning-notes             10331
# 15                                3D-Machine-Learning             10193
# 16                                    machinelearning              9348
# 17                          machine_learning_examples              8911
# 18  state-of-the-art-result-for-machine-learning-p...              8895
# 19                         financial-machine-learning              8750
# 20                                    machinelearning              8706
# 21                             MachineLearning_Python              8580
# 22                        Machine-Learning-Collection              8485
# 23                       machine-learning-cheat-sheet              8042
# 24                           machine-learning-roadmap              7893
# 25                       machine-learning-yearning-cn              7844
# 26           Machine-Learning-Specialization-Coursera              7782
# 27                    Machine-learning-learning-notes              7762
# 28                 Learn_Machine_Learning_in_3_Months              7606
# 29                          industry-machine-learning              7485
#
#             language
# 0             Python
# 1            Unknown
# 2            Unknown
# 3   Jupyter Notebook
# 4            Unknown
# 5   Jupyter Notebook
# 6            Unknown
# 7            Unknown
# 8   Jupyter Notebook
# 9            Unknown
# 10  Jupyter Notebook
# 11           Unknown
# 12              HTML
# 13            Python
# 14  Jupyter Notebook
# 15           Unknown
# 16                C#
# 17            Python
# 18           Unknown
# 19            Python
# 20  Jupyter Notebook
# 21            Python
# 22            Python
# 23               TeX
# 24           Unknown
# 25               CSS
# 26  Jupyter Notebook
# 27           Unknown
# 28           Unknown
# 29  Jupyter Notebook

# %% [markdown]
# 4. Logical Operator: AND
#
# The AND operator is used to combine two conditions. The query finds repositories with more than 10,000 stars that use Python.

# %%
query = """
SELECT name, stargazers_count, language
FROM Repositories
WHERE stargazers_count > 10000
AND language = 'Python'
"""

and_result = pd.read_sql_query(query, conn)

and_result
# Out:
#                                   name  stargazers_count language
# 0                         transformers            164227   Python
# 1                               funNLP             82527   Python
# 2             awesome-machine-learning             74066   Python
# 3                         scikit-learn             66972   Python
# 4                               gradio             43378   Python
# 5                      ML-From-Scratch             32494   Python
# 6   linkedin-skill-assessments-quizzes             28812   Python
# 7                          cs249r_book             27954   Python
# 8                                 onnx             21326   Python
# 9                                 rasa             21295   Python
# 10                      ml-engineering             18655   Python
# 11                            numpy-ml             16334   Python
# 12                              imgaug             14739   Python
# 13                          ChatterBot             14510   Python
# 14                                 nni             14363   Python
# 15                                 ivy             14170   Python
# 16                                 tvm             13669   Python
# 17                            cleanlab             11628   Python
# 18                        MLAlgorithms             11166   Python
# 19                               dolly             10805   Python
# 20                             doccano             10744   Python
# 21                         mlcourse.ai             10687   Python
# 22                    Machine-Learning             10370   Python

# %% [markdown]
# 5. Logical Operator: OR
#
# The OR operator is used to find repositories that use either Python or JavaScript.

# %%
query = """
SELECT name, stargazers_count, language
FROM Repositories
WHERE language = 'Python'
OR language = 'JavaScript'
"""

or_result = pd.read_sql_query(query, conn)

or_result
# Out:
#                                   name  stargazers_count    language
# 0                         transformers            164227      Python
# 1                               funNLP             82527      Python
# 2             awesome-machine-learning             74066      Python
# 3                         scikit-learn             66972      Python
# 4                               gradio             43378      Python
# 5                               netron             33361  JavaScript
# 6                      ML-From-Scratch             32494      Python
# 7   linkedin-skill-assessments-quizzes             28812      Python
# 8                          cs249r_book             27954      Python
# 9                                 onnx             21326      Python
# 10                                rasa             21295      Python
# 11                      ml-engineering             18655      Python
# 12                            numpy-ml             16334      Python
# 13                     transformers.js             16260  JavaScript
# 14                              imgaug             14739      Python
# 15                          ChatterBot             14510      Python
# 16                                 nni             14363      Python
# 17                                 ivy             14170      Python
# 18                                 tvm             13669      Python
# 19                                lime             12165  JavaScript
# 20                            cleanlab             11628      Python
# 21                        MLAlgorithms             11166      Python
# 22                               dolly             10805      Python
# 23                             doccano             10744      Python
# 24                         mlcourse.ai             10687      Python
# 25                    Machine-Learning             10370      Python
# 26                              sktime              9943      Python
# 27           machine_learning_examples              8911      Python
# 28                             pattern              8860      Python
# 29          financial-machine-learning              8750      Python
# 30              MachineLearning_Python              8580      Python
# 31         Machine-Learning-Collection              8485      Python
# 32                        auto-sklearn              8126      Python

# %% [markdown]
# 6. Logical Operator: NOT
#
# The NOT operator is used to exclude repositories that use Python.

# %%
query = """
SELECT name, stargazers_count, language
FROM Repositories
WHERE NOT language = 'Python'
"""

not_result = pd.read_sql_query(query, conn)

not_result
# Out:
#                                                  name  stargazers_count  \
# 0                                          tensorflow            197048
# 1                                    ML-For-Beginners             89495
# 2   500-AI-Machine-learning-Deep-learning-Computer...             36371
# 3                                         C-Plus-Plus             34585
# 4                                              netron             33361
# ..                                                ...               ...
# 65                    Machine-learning-learning-notes              7762
# 66                                  awesome-youtubers              7693
# 67                 Learn_Machine_Learning_in_3_Months              7606
# 68                                              h2o-3              7492
# 69                          industry-machine-learning              7485
#
#             language
# 0                C++
# 1   Jupyter Notebook
# 2            Unknown
# 3                C++
# 4         JavaScript
# ..               ...
# 65           Unknown
# 66          Markdown
# 67           Unknown
# 68  Jupyter Notebook
# 69  Jupyter Notebook
#
# [70 rows x 3 columns]

# %% [markdown]
# 7. Sorting and Limiting Results
#
# The repositories are sorted by the number of stars in descending order. The top 10 repositories are then selected.

# %%
query = """
SELECT name, stargazers_count, language
FROM Repositories
ORDER BY stargazers_count DESC
LIMIT 10
"""

top10 = pd.read_sql_query(query, conn)

top10
# Out:
#                                                 name  stargazers_count  \
# 0                                         tensorflow            197048
# 1                                       transformers            164227
# 2                                   ML-For-Beginners             89495
# 3                                             funNLP             82527
# 4                           awesome-machine-learning             74066
# 5                                       scikit-learn             66972
# 6                                             gradio             43378
# 7  500-AI-Machine-learning-Deep-learning-Computer...             36371
# 8                                        C-Plus-Plus             34585
# 9                                             netron             33361
#
#            language
# 0               C++
# 1            Python
# 2  Jupyter Notebook
# 3            Python
# 4            Python
# 5            Python
# 6            Python
# 7           Unknown
# 8               C++
# 9        JavaScript

# %% [markdown]
# 8. Total Number of Repositories
#
# The COUNT function is used to calculate the total number of repositories in the dataset.

# %%
query = """
SELECT COUNT(*) AS total_repositories
FROM Repositories
"""

total_repositories = pd.read_sql_query(query, conn)

total_repositories
# Out:
#    total_repositories
# 0                 100

# %% [markdown]
# 9. Average Number of Stars
#
# The AVG function is used to calculate the average number of stars across all repositories.

# %%
query = """
SELECT AVG(stargazers_count) AS average_stars
FROM Repositories
"""

average_stars = pd.read_sql_query(query, conn)

average_stars
# Out:
#    average_stars
# 0       20805.28

# %% [markdown]
# 10. Repository Count by Programming Language
#
# Repositories are grouped by programming language. Only programming languages with more than 5 repositories are displayed.

# %%
query = """
SELECT language, COUNT(*) AS repository_count
FROM Repositories
GROUP BY language
HAVING COUNT(*) > 5
ORDER BY repository_count DESC
"""

language_counts = pd.read_sql_query(query, conn)

language_counts
# Out:
#            language  repository_count
# 0            Python                30
# 1           Unknown                23
# 2  Jupyter Notebook                19
# 3               C++                12

# %% [markdown]
# 11. Visualization: Top 10 Most Popular Repositories
#
# A bar chart is created to show the top 10 repositories with the highest number of stars.

# %%
plt.figure(figsize=(12, 6))

plt.bar(top10["name"], top10["stargazers_count"])

plt.xlabel("Repository")
plt.ylabel("Number of Stars")
plt.title("Top 10 Most Popular Machine Learning Repositories")

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_490/1860125515.py:10: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# 12. Repository Creation Trends
#
# The repository creation dates are analyzed by year to identify changes in repository creation activity over time.

# %%
df["created_at"] = pd.to_datetime(df["created_at"])

df["creation_year"] = df["created_at"].dt.year

creation_trends = (
    df.groupby("creation_year")
      .size()
      .reset_index(name="repository_count")
)

creation_trends
# Out:
#     creation_year  repository_count
# 0            2009                 1
# 1            2010                 2
# 2            2011                 2
# 3            2013                 3
# 4            2014                 6
# 5            2015                 7
# 6            2016                14
# 7            2017                17
# 8            2018                18
# 9            2019                 7
# 10           2020                10
# 11           2021                 6
# 12           2022                 3
# 13           2023                 3
# 14           2024                 1

# %%
plt.figure(figsize=(10, 6))

plt.plot(
    creation_trends["creation_year"],
    creation_trends["repository_count"],
    marker="o"
)

plt.xlabel("Year")
plt.ylabel("Number of Repositories")
plt.title("Machine Learning Repository Creation Trends")

plt.tight_layout()
plt.show()

# %% [markdown]
# 13. Findings and Insights
#
# The SQL analysis and visualizations were used to identify important patterns in the GitHub Machine Learning repositories dataset.
#
# The Top 10 analysis identifies the repositories with the highest number of stars, showing which projects are the most popular within the collected dataset.
#
# The programming language analysis identifies the languages with more than 5 repositories and shows which programming languages are most common in the dataset.
#
# The repository creation trend shows how repository creation activity has changed over the years.
#
# The filtering and logical operator queries provide additional information about repositories based on their popularity and programming languages.

# %% [markdown]
# 14. Close the Database
#
# The SQLite database connection is closed after completing the analysis.

# %%
conn.close()

print("SQLite database connection closed successfully.")
# Out:
# SQLite database connection closed successfully.
